# %% [markdown]
# # Assignments
# ---
# ### Instructions:
# #### 1. Use Latex programming to show your solution.
# #### 2. For problems requiring the identification of reflexive, symmetric, and transitive properties of relation, show both manual solution via latex, and the solution using your python function.
# ---
# * Given $A = \{1,2,3,4\}$ and $B=\{x,y,z\}$. Let $R$ be a relation from $A \to B$:
# \begin{equation}
# \textbf{R} = \{
# \{1,y\},\{1,z\},\{3,y\},\{4,x\},\{4,z\}
# \}
# \end{equation}
# 1. Find all $aRb$.
# 2. Find $R^{-1}$.
# 3. Determine the domain and range of $R$.
# 4. Check if $R$ is a reflexive relation.
# 5. Check if $R$ is a symmetric relation.
# <br>
# <br>
# <br>

# %% [markdown]
# 1. Find all $aRb$.
# \begin{equation}
# aRb = \{
# \{1,y\},\{1,z\},\{3,y\},\{4,x\},\{4,z\}
# \}
# \end{equation}

# %% [markdown]
# 2. Find $R^{-1}$.
#
#    The inverse relation $R^{-1}$ is the set of all ordered pairs (b,a) such that (a,b)∈R. Therefore,
#
# \begin{equation} R^{-1} = \{\{y,1\},\{z,1\},\{y,3\},\{x,4\},\{z,4\}\} \end{equation}

# %% [markdown]
# 3. Determine the domain and range of $R$.
# \begin{equation}
# \text{Domain of } R = \{
# 1,2,3
# \}\end{equation}
# \begin{equation}
# \text{Range of } R = \{
# x,y,z
# \}\end{equation}

# %% [markdown]
# 4. Check if $R$ is a reflexive relation.
#
#    A relation R on a set A is reflexive if and only if for every element a in A, there exists an ordered pair (a,a) in R.

# %%
def is_reflexive(A, R):
    for a in A:
        if (a, a) not in R:
            return False
    return True

A = {1, 2, 3, 4}
B = {'x', 'y', 'z'}
R = {(1, 'y'), (1, 'z'), (3, 'y'), (4, 'x'), (4, 'z')}

result = is_reflexive(A, R)
print(f"R is a reflexive relation? {result}")  

import networkx as nx
import matplotlib.pyplot as plt

G = nx.DiGraph()
G.add_nodes_from(A)
G.add_nodes_from(B)
G.add_edges_from(R)

nx.draw(G, with_labels=True)
plt.show()
# Out:
# R is a reflexive relation? False

# %% [markdown]
# 5. Check if $R$  is a symmetric relation.
#
#    A relation R is symmetric if and only if for every pair (a,b) in R, the pair (b,a) is also in R.

# %%
def is_symmetric(R):
    for a, b in R:
        if (b, a) not in R:
            return False
    return True

R = {(1, 'y'), (1, 'z'), (3, 'y'), (4, 'x'), (4, 'z')}

print(f"R is a symmetric relation? {is_symmetric(R)}")

import networkx as nx
import matplotlib.pyplot as plt

R = {(1, 'y'), (1, 'z'), (3, 'y'), (4, 'x'), (4, 'z')}

G = nx.DiGraph()
G.add_edges_from(R)

nx.draw(G, with_labels=True)
plt.show()
# Out:
# R is a symmetric relation? False

# %% [markdown]
# * Given $A = \{1,2,3,4\}$,$C=\{a,b,c\}$, and $C=\{x,y,z\}$. Let $R$ be a relation from $A \to B$:
# \begin{equation}
# \textbf{R} = \{
# \{1,b\},\{2,a\},\{2,c\}
# \}
# \end{equation}
# <br>
# Also Let $S$ be a relation from $B \to C$:
# \begin{equation}
# \textbf{S} = \{
# \{a,y\},\{b,x\},\{c,y\},,\{c,z\}
# \}
# \end{equation}
# 1. Find the composition relation $\textbf{R}\circ\textbf{S}$.
# 2. Find $R^{-1}$.
# 3. Find $S^{-1}$.
# 4. Determine the domain and range of $R$.
# 5. Check if $R$ is a reflexive relation.
# 6. Check if $R$ is a symmetric relation.
# 7. Determine the domain and range of $S$.
# 8. Check if $S$ is a reflexive relation.
# 9. Check if $S$ is a symmetric relation.
#
# <br>

# %% [markdown]
# 1. Find the composition relation $\textbf{R}\circ\textbf{S}$.
#
#    \begin{equation}
#    \textbf{R} \circ \textbf{S} = \{ \{1,x\}, \{2,y\}, \{2,z\} \}
#    \end{equation}

# %% [markdown]
# 2. Find $R^{-1}$.
#    \begin{equation}
#    R^{-1} = \{ \{b,1\}, \{a,2\}, \{c,2\} \} \end{equation}

# %% [markdown]
# 3. Find $S^{-1}$.
# \begin{equation}
# S^{-1} = \{ \{y,a\}, \{x,b\}, \{y,c\}, \{z,c\} \} \end{equation}

# %% [markdown]
# 4. Determine the domain and range of $R$.
# \begin{equation}
# \text{Domain of }R: \{1,2\}
# \end{equation}
# \begin{equation}
# \text{Range of }R: \{a,b,c\}
# \end{equation}

# %% [markdown]
# 5. Check if $R$ is a reflexive relation
# 6. Check if $R$ is a symmetric relation

# %%
def is_reflexive(A, R):

    for a in A:
        if (a, a) not in R:
            return False
    return True

def is_symmetric(R):
    for a, b in R:
        if (b, a) not in R:
            return False
    return True
    
A = {1, 2, 3, 4}
B = {'a', 'b', 'c'}
C = {'x', 'y', 'z'}

R = {(1, 'b'), (2, 'a'), (2, 'c')}

print(f"R is reflexive? {is_reflexive(A, R)}")

print(f"R is symmetric? {is_symmetric(R)}")
# Out:
# R is reflexive? False
# R is symmetric? False

# %% [markdown]
# 7. Determine the domain and range of $S$.
# \begin{equation}
# \text{Domain of }S: \{a,b,c\}
# \end{equation}
# \begin{equation}
# \text{Range of }S: \{x,y,z\}
# \end{equation}

# %% [markdown]
# 8. Check if $S$ is a reflexive relation.
# 9. Check if $S$ is a symmetric relation.

# %%
def is_reflexive(relation, set_):
    for element in set_:
        if (element, element) not in relation:
            return False
    return True

def is_symmetric(relation):
    for pair in relation:
        if (pair[1], pair[0]) not in relation:
            return False
    return True

B = {'a','b','c'}
C = {'x','y','z'}
S = {('a','y'),('b','x'),('c','y'),('c','z')}

print(f"S is reflexive: {is_reflexive(S, B)}")

print(f"S is symmetric: {is_symmetric(S)}")
# Out:
# S is reflexive: False
# S is symmetric: False

# %% [markdown]
# * Given $A = \{1,2,3,4\}$. Let $R$ be a relation from $A \to B$:
# \begin{equation}
# \textbf{R} = \{
# \{1,1\},\{2,2\},\{2,3\},\{3,2\},\{4,2\},\{4,4\}
# \}
# \end{equation}
# <br>
# 1. Find the composition relation $\textbf{R}\circ\textbf{R}$.<br>
# 2. Draw the directed graph of $R^{-1}$.
# 3. Draw the directed graph of $R$.<br><br><br>

# %% [markdown]
# 1.
# The composition relation R∘R is defined as:
# $$
# R \circ R = \{(a,c) \mid (a,b) \in R \text{ and } (b,c) \in R \text{ for some } b \in A\}
# $$
# In this case,
#
# \begin{equation}
# R∘R = \{
# \{1,1\},\{2,2\},\{2,3\},\{3,3\},\{4,2\}, \{4,4\}
# \}
# \end{equation}

# %% [markdown]
# 2. The inverse of a relation $R$ is defined as:
#
# \begin{equation}
# R^{-1} = {(b,a) \mid (a,b) \in R}
# \end{equation}
# Therefore, if
# \begin{equation}
# R = \{\{1,1\},\{2,2\},\{3,2\},\{2,3\},\{2,4\},\{4,4\}\}
# \end{equation}
# then:
# \begin{equation}
# R^{-1} = \{\{1,1\},\{2,2\},\{3,2\},\{2,3\},\{4,2\}\}
# \end{equation}

# %%
import networkx as nx
import matplotlib.pyplot as plt

R_inverse = {(1, 1), (2, 2), (3, 2), (2, 3), (2, 4), (4, 4)}

G = nx.DiGraph()
G.add_edges_from(R_inverse)

nx.draw(G, with_labels=True)
plt.show()

# %% [markdown]
# 3. Directed graph of $R$.

# %%
import networkx as nx
import matplotlib.pyplot as plt

R = {(1, 1), (2, 2), (2, 3), (3, 2), (4, 2), (4, 4)}

G = nx.DiGraph()
G.add_edges_from(R)

nx.draw(G, with_labels=True)
plt.show()

# %% [markdown]
# * Let $R$ and $S$ be relations on $A = \{1,2,3\}$<br>
# let:<br>
# $\textbf{R} = \{
# \{1,1\},\{1,2\},\{2,3\},\{3,1\},\{3,3\}
# \}$<br>
# let:<br>
# $\textbf{S} = \{
# \{1,2\},\{1,3\},\{2,1\},\{3,3\}
# \}$<br>
# Find:<br>
# 1. $R \cup S$.<br>
# 2. $R \cap S$.<br>
# 3. $R^{c}$.<br>
# 4. $R \circ S$.<br>
# 5. $S \circ S$.<br><br><br>

# %% [markdown]
# 1. $R \cup S$ $ = \{
# \{1,1\},\{1,2\},\{2,3\},\{3,1\},\{3,3\}
# ,\{1,3\},\{2,1\}\}$

# %% [markdown]
# 2. $R \cap S$ $ = \{ \{1,2\}, \{3,3\}
# \}$

# %% [markdown]
# 3. $R^{c}$ $ = \{ \{1,3\}, \{2,1\}, \{2,2\}
# \}$

# %% [markdown]
# 4. $R \circ S$ $ = \{ \{1,1\}, \{1,3\}, \{2,2\}, \{2,3\}, \{3,2\}, \{3,3\}
# \}$

# %% [markdown]
# 5. $S \circ S$ $ = \{ \{1,1\}, \{1,3\}, \{2,2\}, \{2,3\}, \{3,3\}
# \}$

# %% [markdown]
# * Consider the five relations on the set $A = \{1,2,3\}$:
# \begin{equation}
# \textbf{R} = \{
# \{1,1\},\{1,2\},\{1,3\},\{3,3\}
# \}
# \end{equation}
# <br>
# \begin{equation}
# \textbf{S} = \{
# \{1,1\},\{1,2\},\{2,1\},\{2,2\},\{3,3\}
# \}
# \end{equation}
# <br>
# \begin{equation}
# \textbf{T} = \{
# \{1,1\},\{1,2\},\{2,2\},\{2,3\},
# \}
# \end{equation}
# <br>
# Which of the relations above are:<br>
# 1. Reflexive.<br>
# 2. Symmetric or anti-symmetric.<br>
# 3. Transitive.

# %% [markdown]
# 1. A relation is reflexive if every element is related to itself. That is, for all a in A, {a,a} is in the relation.
#
#    R is not reflexive because {2,2} is missing.
#
#    S and T are reflexive because for all a in A, {a,a} is in the relation.

# %% [markdown]
# 2. A relation is symmetric if the pair (a,b) is in the relation then (b,a) must also be in the relation.
#
# A relation is anti-symmetric if the pair (a,b) is in the relation and (b,a) is also in the relation, then a must be equal to b.
#
#
# S is symmetric because for every pair (a,b), the pair (b,a) is also in the relation.

# %% [markdown]
# 3. A relation is transitive if whenever an element a is related to an element b, and that element b is related to an element c, then a is also related to c

# %% [markdown]
# R and S are not transitive because for R, {1,3} and {3,3} are in R but {1,3} is not in R. For S, {1,2} and {2,1} are in S but {1,1} is not in S.

# %% [markdown]
# T is transitive because for every pair of elements (a,b) and (b,c) in T, the pair (a,c) is also in T.
